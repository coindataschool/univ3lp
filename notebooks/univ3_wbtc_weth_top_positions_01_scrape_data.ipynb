# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.chrome.service import Service
from time import sleep
import os
import pandas as pd

pd.set_option('display.max_columns', 15)
pd.set_option('display.max_rows', 50)
pd.options.display.float_format = '{:,.4f}'.format

# %% [markdown]
# ## Scrape Top WBTC-WETH Uniswap V3 Pools from revert finance
#
# We now scrape this table of [Top Pools](https://revert.finance/#/top-positions?sort=underlying_value&underlying-value-from=20000&apr-from=20&token1=0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2&token0=0x2260fac5e5542a773aa44fbcfedf7c193bc2c599&age-from=14) and put the info in a data frame.

# %%
# set up
chrome_options = Options()
chrome_options.add_argument('disable-notifications')
chrome_options.add_argument('start-maximized')
chrome_options.add_argument("disable-infobars")
s = Service('/Applications/chromedriver')

# %%
browser = webdriver.Chrome(service=s, options = chrome_options)
url = 'https://revert.finance/#/top-positions?sort=underlying_value&underlying-value-from=20000&apr-from=20&token1=0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2&token0=0x2260fac5e5542a773aa44fbcfedf7c193bc2c599&age-from=14'
browser.get(url)
delay = 20 #secods
WebDriverWait(browser, delay)
sleep(delay) # need to wait until the page is fully loaded before scraping

# scrape page and parse
html = browser.execute_script("return document.getElementsByTagName('html')[0].innerHTML")
soup = BeautifulSoup(html, "html.parser")

# close browser
browser.close()

# %%
# extract table header
header1 = [item.text for item in soup.find_all("span", class_='text-gray-20')]
header2 = [item_n.text for item_n in soup.find_all('a', class_='text-gray-20 visited:text-gray-20 hover:text-white active:gray-40')]
header = [header1[0]] + header2[:3] + [header1[1]] + header2[3:]

# %%
# extract pool/fees column
pool_fees = [item.text for item in soup.find_all("span", class_='text-gray-30')]

# extract nft_id/owner column
pool_links = ['https://revert.finance'+item.get('href') for item in soup.find_all('a', class_="underline text-green-40 visited:text-green-40 hover:text-green-20 active:green-60")]

# %%
# extract PnL, APR, fee APR, value columns
ha = [item.text for item in soup.find_all('div', class_="text-ellipsis overflow-hidden whitespace-nowrap")]

pnls = []
aprs = []
fee_aprs = []
vals = []
for i in range(len(ha)):
    j = i%4
    if j==0:
        pnls.append(ha[i])
    elif j==1:
        aprs.append(ha[i])
    elif j==2:
        fee_aprs.append(ha[i])
    elif j==3:
        vals.append(ha[i])
    else:
        pass

# %%
# extract age column
age_days = [item.text for item in soup.find_all('div', class_="border-b border-gray-70 transition-all ease-linear delay-30 duration-150 text-sm h-[60px] group-hover:bg-gray-90 flex items-center group-last:border-transparent group-hover:border-b-gray-70 justify-end pl-4 w-32 text-gray-30")]

# %%
# scrape the price range for each of these top pools 
price_rngs = []
for url in pool_links:
    browser = webdriver.Chrome(service=s, options = chrome_options)
    browser.get(url)
    delay = 30 #secods, increase this number if throws error
    WebDriverWait(browser, delay)
    sleep(delay) # need to wait until the page is fully loaded before scraping

    # scrape page and parse
    html = browser.execute_script("return document.getElementsByTagName('html')[0].innerHTML")
    soup = BeautifulSoup(html, "html.parser")

    # close browser
    browser.close() 
    
    # extract price range
    price_range = [item.text for item in soup.find_all('div', class_='lp-assets') if item.text.__contains__('WBTC/WETH')][0].split(' WBTC/WETH')[0]
    price_rngs.append(price_range)

# %%
df = pd.DataFrame({'pool/fees':pool_fees, 'nft_id/owner':pool_links, 'PnL': pnls, 
                   'APR':aprs, 'fee APR':fee_aprs, 'value':vals, 'age':age_days, 'price_range':price_rngs,})
df
# Out:
#    pool/fees                                       nft_id/owner          PnL  \
# 0      0.30%  https://revert.finance/#/uniswap-position/main...   $85,084.14
# 1      0.30%  https://revert.finance/#/uniswap-position/main...  $142,183.59
# 2      0.30%  https://revert.finance/#/uniswap-position/main...   $40,051.53
# 3      0.30%  https://revert.finance/#/uniswap-position/main...   $37,183.85
# 4      0.30%  https://revert.finance/#/uniswap-position/main...  $162,142.64
# 5      0.30%  https://revert.finance/#/uniswap-position/main...   $33,903.50
# 6      0.30%  https://revert.finance/#/uniswap-position/main...   $12,674.21
# 7      0.30%  https://revert.finance/#/uniswap-position/main...   $19,732.69
# 8      0.30%  https://revert.finance/#/uniswap-position/main...   $18,400.48
# 9      0.30%  https://revert.finance/#/uniswap-position/main...   $22,634.59
# 10     0.30%  https://revert.finance/#/uniswap-position/main...   $16,692.60
# 11     0.05%  https://revert.finance/#/uniswap-position/main...    $8,984.16
# 12     0.30%  https://revert.finance/#/uniswap-position/main...   $14,189.58
# 13     0.30%  https://revert.finance/#/uniswap-position/main...   $12,328.08
# 14     0.05%  https://revert.finance/#/uniswap-position/main...    $9,375.89
# 15     0.05%  https://revert.finance/#/uniswap-position/main...    $8,225.36
# 16     0.30%  https://revert.finance/#/uniswap-position/main...   $12,906.76
# 17     0.30%  https://revert.finance/#/uniswap-position/main...    $5,371.65
# 18     0.30%  https://revert.finance/#/uniswap-position/main...    $2,581.34
# 19     0.30%  https://revert.finance/#/uniswap-position/main...    $3,611.19
# 20     0.30%  https://revert.finance/#/uniswap-position/main...      $567.17
# 21     0.30%  https://revert.finance/#/uniswap-position/main...    $6,068.26
# 22     0.05%  https://revert.finance/#/uniswap-position/main...    $2,667.12
# 23     0.30%  https://revert.finance/#/uniswap-position/main...    $1,165.64
# 24     0.30%  https://revert.finance/#/uniswap-position/main...    $1,112.93
# 25     0.05%  https://revert.finance/#/uniswap-position/main...    $1,704.00
# 26     0.30%  https://revert.finance/#/uniswap-position/main...      $932.68
# 27     0.30%  https://revert.finance/#/uniswap-position/main...      $932.85
# 28     0.05%  https://revert.finance/#/uniswap-position/main...    $4,474.53
# 29     0.30%  https://revert.finance/#/uniswap-position/main...    $7,075.53
# 30     0.30%  https://revert.finance/#/uniswap-position/main...      $833.89
#
#         APR  fee APR          value         age        price_range
# 0    20.30%   20.39%  $2,804,470.28   54.5 days  11.5061 - 15.1631
# 1    67.14%   37.43%    $822,076.02   76.1 days  12.1445 - 13.6928
# 2    27.46%   27.54%    $814,482.37   69.5 days  13.6108 - 15.9086
# 3    23.96%   23.99%    $756,293.96   74.9 days  13.0511 - 15.3461
# 4    20.68%   20.95%    $731,351.51  460.3 days  12.1445 - 16.1975
# 5    23.86%   23.96%    $692,087.80   74.9 days  13.0511 - 15.3461
# 6    87.56%   91.74%    $657,723.03   15.2 days  12.3650 - 14.5394
# 7    20.82%   20.96%    $629,284.50   55.0 days  11.7151 - 15.6248
# 8    20.65%   21.43%    $463,959.90   87.0 days  11.3008 - 15.2543
# 9    20.63%   25.99%    $356,716.93  110.4 days  12.0718 - 15.9086
# 10   23.82%   23.95%    $341,125.97   75.0 days  13.0511 - 15.3461
# 11   24.65%   24.78%    $255,115.51   52.1 days  12.4768 - 15.3768
# 12   26.44%   29.79%    $247,074.03   78.7 days  13.0511 - 15.3461
# 13   26.43%   29.79%    $214,708.89   78.7 days  13.0511 - 15.3461
# 14   20.55%   21.47%    $212,414.19   99.9 days  11.3008 - 16.5082
# 15   27.50%   30.04%    $127,992.89   86.2 days  12.2542 - 14.2801
# 16   40.37%   40.43%    $107,849.13  108.2 days  12.4394 - 13.2086
# 17   21.31%   22.26%    $103,823.76   88.4 days  11.8565 - 16.1006
# 18   21.76%   22.39%     $76,526.81   56.5 days  11.4373 - 15.9086
# 19   23.86%   24.73%     $61,502.71   89.6 days  12.4394 - 14.1097
# 20   31.12%   36.23%     $54,553.84   15.8 days  11.3688 - 16.2950
# 21   21.43%   22.94%     $54,533.02  190.2 days  12.3650 - 15.3461
# 22   27.11%   34.14%     $41,637.39   84.8 days  12.3527 - 14.9523
# 23   21.42%   25.63%     $39,793.05   49.6 days  12.5143 - 15.3461
# 24   21.73%   22.13%     $34,606.05   54.0 days  11.8565 - 14.7149
# 25   22.88%   23.76%     $32,896.32   82.5 days  11.1104 - 14.7002
# 26   21.29%   25.71%     $32,150.03   49.4 days  12.5143 - 15.3461
# 27   63.69%   66.82%     $29,444.72   18.9 days  12.5143 - 14.8926
# 28   28.10%   28.50%     $26,467.21  219.1 days  12.5268 - 13.6791
# 29   21.63%   22.00%     $22,919.19  518.2 days  14.1947 - 16.6908
# 30  102.48%  109.91%     $22,126.15   16.5 days  12.6654 - 13.6108

# %% [markdown]
# ## Clean the data and save as csv

# %%
# clean data
df['PnL'] = df.PnL.str.strip('$').str.replace(',', '').astype(float)
df['APR'] = df.APR.str.strip('%').astype(float)
df['fee APR'] = df['fee APR'].str.strip('%').astype(float)
df['value'] = df.value.str.strip('$').str.replace(',', '').astype(float)
df['age'] = df.age.str.replace(' days', '').astype(float)
df['price_lwr'], df['price_upr'] = zip(*df.price_range.str.split(' - '))

# %%
df = df.rename(columns={'nft_id/owner':'url'})
df.columns = df.columns.str.replace('/| ', '_', regex=True)
df = df.drop(columns='price_range')
df
# Out:
#    pool_fees                                                url          PnL  \
# 0      0.30%  https://revert.finance/#/uniswap-position/main...  85,084.1400
# 1      0.30%  https://revert.finance/#/uniswap-position/main... 142,183.5900
# 2      0.30%  https://revert.finance/#/uniswap-position/main...  40,051.5300
# 3      0.30%  https://revert.finance/#/uniswap-position/main...  37,183.8500
# 4      0.30%  https://revert.finance/#/uniswap-position/main... 162,142.6400
# 5      0.30%  https://revert.finance/#/uniswap-position/main...  33,903.5000
# 6      0.30%  https://revert.finance/#/uniswap-position/main...  12,674.2100
# 7      0.30%  https://revert.finance/#/uniswap-position/main...  19,732.6900
# 8      0.30%  https://revert.finance/#/uniswap-position/main...  18,400.4800
# 9      0.30%  https://revert.finance/#/uniswap-position/main...  22,634.5900
# 10     0.30%  https://revert.finance/#/uniswap-position/main...  16,692.6000
# 11     0.05%  https://revert.finance/#/uniswap-position/main...   8,984.1600
# 12     0.30%  https://revert.finance/#/uniswap-position/main...  14,189.5800
# 13     0.30%  https://revert.finance/#/uniswap-position/main...  12,328.0800
# 14     0.05%  https://revert.finance/#/uniswap-position/main...   9,375.8900
# 15     0.05%  https://revert.finance/#/uniswap-position/main...   8,225.3600
# 16     0.30%  https://revert.finance/#/uniswap-position/main...  12,906.7600
# 17     0.30%  https://revert.finance/#/uniswap-position/main...   5,371.6500
# 18     0.30%  https://revert.finance/#/uniswap-position/main...   2,581.3400
# 19     0.30%  https://revert.finance/#/uniswap-position/main...   3,611.1900
# 20     0.30%  https://revert.finance/#/uniswap-position/main...     567.1700
# 21     0.30%  https://revert.finance/#/uniswap-position/main...   6,068.2600
# 22     0.05%  https://revert.finance/#/uniswap-position/main...   2,667.1200
# 23     0.30%  https://revert.finance/#/uniswap-position/main...   1,165.6400
# 24     0.30%  https://revert.finance/#/uniswap-position/main...   1,112.9300
# 25     0.05%  https://revert.finance/#/uniswap-position/main...   1,704.0000
# 26     0.30%  https://revert.finance/#/uniswap-position/main...     932.6800
# 27     0.30%  https://revert.finance/#/uniswap-position/main...     932.8500
# 28     0.05%  https://revert.finance/#/uniswap-position/main...   4,474.5300
# 29     0.30%  https://revert.finance/#/uniswap-position/main...   7,075.5300
# 30     0.30%  https://revert.finance/#/uniswap-position/main...     833.8900
#
#         APR  fee_APR          value      age price_lwr price_upr
# 0   20.3000  20.3900 2,804,470.2800  54.5000   11.5061   15.1631
# 1   67.1400  37.4300   822,076.0200  76.1000   12.1445   13.6928
# 2   27.4600  27.5400   814,482.3700  69.5000   13.6108   15.9086
# 3   23.9600  23.9900   756,293.9600  74.9000   13.0511   15.3461
# 4   20.6800  20.9500   731,351.5100 460.3000   12.1445   16.1975
# 5   23.8600  23.9600   692,087.8000  74.9000   13.0511   15.3461
# 6   87.5600  91.7400   657,723.0300  15.2000   12.3650   14.5394
# 7   20.8200  20.9600   629,284.5000  55.0000   11.7151   15.6248
# 8   20.6500  21.4300   463,959.9000  87.0000   11.3008   15.2543
# 9   20.6300  25.9900   356,716.9300 110.4000   12.0718   15.9086
# 10  23.8200  23.9500   341,125.9700  75.0000   13.0511   15.3461
# 11  24.6500  24.7800   255,115.5100  52.1000   12.4768   15.3768
# 12  26.4400  29.7900   247,074.0300  78.7000   13.0511   15.3461
# 13  26.4300  29.7900   214,708.8900  78.7000   13.0511   15.3461
# 14  20.5500  21.4700   212,414.1900  99.9000   11.3008   16.5082
# 15  27.5000  30.0400   127,992.8900  86.2000   12.2542   14.2801
# 16  40.3700  40.4300   107,849.1300 108.2000   12.4394   13.2086
# 17  21.3100  22.2600   103,823.7600  88.4000   11.8565   16.1006
# 18  21.7600  22.3900    76,526.8100  56.5000   11.4373   15.9086
# 19  23.8600  24.7300    61,502.7100  89.6000   12.4394   14.1097
# 20  31.1200  36.2300    54,553.8400  15.8000   11.3688   16.2950
# 21  21.4300  22.9400    54,533.0200 190.2000   12.3650   15.3461
# 22  27.1100  34.1400    41,637.3900  84.8000   12.3527   14.9523
# 23  21.4200  25.6300    39,793.0500  49.6000   12.5143   15.3461
# 24  21.7300  22.1300    34,606.0500  54.0000   11.8565   14.7149
# 25  22.8800  23.7600    32,896.3200  82.5000   11.1104   14.7002
# 26  21.2900  25.7100    32,150.0300  49.4000   12.5143   15.3461
# 27  63.6900  66.8200    29,444.7200  18.9000   12.5143   14.8926
# 28  28.1000  28.5000    26,467.2100 219.1000   12.5268   13.6791
# 29  21.6300  22.0000    22,919.1900 518.2000   14.1947   16.6908
# 30 102.4800 109.9100    22,126.1500  16.5000   12.6654   13.6108

# %%
os.makedirs('../data', exit_ok=True)
df.to_csv('../data/univ3_wbtc_weth_lp_top_positions.csv')
